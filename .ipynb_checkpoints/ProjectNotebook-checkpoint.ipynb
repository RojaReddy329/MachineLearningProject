# %%
import pandas as pd
from pandas.tseries.offsets import BDay

isBusinessDay = BDay().onOffset
eth = 'Datasets/ETH2.csv'
eth_df = pd.read_csv(eth)
match_series = pd.to_datetime(eth_df['Date']).map(isBusinessDay)
eth_df = eth_df[match_series]
eth_df
# Out:
# /Users/sareddyrojareddy/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py:870: FutureWarning: onOffset is a deprecated, use is_on_offset instead
#   new_values = map_f(values, mapper)
#            Date     Price      Open      High       Low     Vol. Change %
# 0      1-Mar-22  2,949.28  2,922.44  3,036.59  2,858.54  917.00K    0.92%
# 1     28-Feb-22  2,922.50  2,616.34  2,949.44  2,574.12  899.19K   11.70%
# 4     25-Feb-22  2,767.53  2,596.52  2,830.31  2,573.39  828.87K    6.59%
# 5     24-Feb-22  2,596.52  2,578.54  2,732.02  2,303.07    1.85M    0.71%
# 6     23-Feb-22  2,578.15  2,637.38  2,749.80  2,578.15  636.50K   -2.20%
# ...         ...       ...       ...       ...       ...      ...      ...
# 2176  16-Mar-16     12.88     13.06     13.89     12.62   19.24K   -1.38%
# 2177  15-Mar-16     13.06     12.63     13.42     11.98   39.73K    4.48%
# 2178  14-Mar-16      12.5     15.07     15.07      11.4   92.18K  -17.05%
# 2181  11-Mar-16     11.95     11.75     11.95     11.75    0.18K    1.70%
# 2182  10-Mar-16     11.75      11.2     11.85     11.07    0.00K    4.91%
#
# [1559 rows x 7 columns]

# %%
bitcoin = 'Datasets/Bitcoin.csv'
bitcoin_df = pd.read_csv(bitcoin)
match_series_bitcoin = pd.to_datetime(bitcoin_df['Date']).map(isBusinessDay)
bitcoin_df = bitcoin_df[match_series_bitcoin]
bitcoin_df
# Out:
# /Users/sareddyrojareddy/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py:870: FutureWarning: onOffset is a deprecated, use is_on_offset instead
#   new_values = map_f(values, mapper)
#             Date  Close/Last  Volume     Open     High      Low
# 0     02/28/2022     43331.5     NaN  37818.6  43638.6  42890.9
# 3     02/25/2022     39443.6     NaN  38927.2  40094.5  39166.3
# 4     02/24/2022     38756.5     NaN  34912.1  38991.0  38167.0
# 5     02/23/2022     35078.8     NaN  37760.5  37417.3  34594.1
# 6     02/22/2022     37982.8     NaN  36576.5  38329.9  37598.7
# ...          ...         ...     ...      ...      ...      ...
# 1015  03/14/2019      3879.8     NaN   3864.6   3914.7   3828.4
# 1016  03/13/2019      3864.9     NaN   3887.6   3894.7   3847.4
# 1017  03/12/2019      3886.0     NaN   3870.3   3900.1   3817.1
# 1018  03/11/2019      3865.1     NaN   3915.6   3935.5   3842.4
# 1021  03/08/2019      3865.9     NaN   3875.1   3929.0   3810.7
#
# [728 rows x 6 columns]

# %%
#Reading tesla,gold and S&P
tesla_df = pd.read_csv('Datasets/Tesla.csv')
tesla_df = tesla_df.rename(columns={"Close/Last": "Last_tesla","Volume":"Trading_Volume_Tesla","Open": "Open_tesla","High": "High_tesla","Low": "Low_tesla"})


gold_df = pd.read_csv('Datasets/Gold.csv')
gold_df = gold_df.rename(columns={"Close/Last": "Last_gold","Volume":"Trading_Volume_Gold","Open": "Open_gold","High": "High_gold","Low": "Low_gold"})


sp_df = pd.read_csv('Datasets/SP500.csv')
sp_df = sp_df.rename(columns={"Close/Last": "Last_SP","Volume":"Trading_Volume_SP","Open": "Open_SP","High": "High_SP","Low": "Low_SP"})
sp_df
# Out:
#             Date  Last_SP Trading_Volume_SP  Open_SP  High_SP   Low_SP
# 0     02/28/2022  4373.94                --  4354.17  4388.84  4315.12
# 1     02/25/2022  4384.65                --  4298.38  4385.34  4286.83
# 2     02/24/2022  4288.70                --  4155.77  4294.73  4114.65
# 3     02/23/2022  4225.50                --  4324.93  4341.51  4221.51
# 4     02/22/2022  4304.76                --  4332.74  4362.12  4267.11
# ...          ...      ...               ...      ...      ...      ...
# 2546  03/07/2012  1352.63                --  1343.39  1354.85  1343.39
# 2547  03/06/2012  1343.36                --  1363.63  1363.63  1340.03
# 2548  03/05/2012  1364.33                --  1369.59  1369.59  1359.13
# 2549  03/02/2012  1369.63                --  1374.09  1374.53  1366.42
# 2550  03/01/2012  1374.09                --  1365.90  1376.17  1365.90
#
# [2551 rows x 6 columns]

# %%
#rename columns
eth_df = eth_df.rename(columns ={"Price": "Last_eth","Open": "Open_eth","High": "High_eth","Low": "Low_eth"})
bitcoin_df = bitcoin_df.rename(columns={"Close/Last": "Last_bitcoin","Open": "Open_bitcoin","High": "High_bitcoin","Low": "Low_bitcoin"})

#create dataframe using ETH and Bitcoin datasets
crypto = pd.DataFrame(eth_df,columns=['Date','Last_eth', 'Open_eth', 'High_eth', 'Low_eth'])

crypto = crypto.join(bitcoin_df['Last_bitcoin'])
crypto = crypto.join(bitcoin_df['Open_bitcoin'])
crypto = crypto.join(bitcoin_df['High_bitcoin'])
crypto = crypto.join(bitcoin_df['Low_bitcoin'])
crypto = crypto.join(tesla_df['Last_tesla'])
crypto = crypto.join(tesla_df['Trading_Volume_Tesla'])
crypto = crypto.join(gold_df['Last_gold'])
crypto = crypto.join(gold_df['Trading_Volume_Gold'])
crypto = crypto.join(sp_df['Last_SP'])

crypto = crypto.dropna()
crypto
# Out:
#            Date  Last_eth  Open_eth  High_eth   Low_eth  Last_bitcoin  \
# 0      1-Mar-22  2,949.28  2,922.44  3,036.59  2,858.54       43331.5
# 4     25-Feb-22  2,767.53  2,596.52  2,830.31  2,573.39       38756.5
# 5     24-Feb-22  2,596.52  2,578.54  2,732.02  2,303.07       35078.8
# 6     23-Feb-22  2,578.15  2,637.38  2,749.80  2,578.15       37982.8
# 7     22-Feb-22  2,636.13  2,569.19  2,663.01  2,501.40       36714.9
# ...         ...       ...       ...       ...       ...           ...
# 1007  29-May-19    268.61    271.16    273.72    260.85        5944.2
# 1014  22-May-19    244.34     253.7     259.7    241.68        3926.7
# 1015  21-May-19    253.76    250.72    261.59    246.85        3879.8
# 1016  20-May-19    250.72    259.68    259.68    238.64        3864.9
# 1021  15-May-19    248.15    217.34    249.78    217.32        3865.9
#
#       Open_bitcoin  High_bitcoin  Low_bitcoin Last_tesla  \
# 0          37818.6       43638.6      42890.9    $870.43
# 4          34912.1       38991.0      38167.0    $821.53
# 5          37760.5       37417.3      34594.1    $856.98
# 6          36576.5       38329.9      37598.7    $876.35
# 7          38935.8       37421.1      36399.6    $923.39
# ...            ...           ...          ...        ...
# 1007        5692.5        5944.2       5745.5    $68.612
# 1014        3882.7        3935.7       3874.8    $67.098
# 1015        3864.6        3914.7       3828.4    $66.813
# 1016        3887.6        3894.7       3847.4    $64.462
# 1021        3875.1        3929.0       3810.7        $69
#
#       Trading_Volume_Tesla  Last_gold  Trading_Volume_Gold  Last_SP
# 0                 33002290     1900.7             239416.0  4373.94
# 4                 27762730     1907.4             323210.0  4304.76
# 5                 22833950     1899.8             155484.0  4348.87
# 6                 18392810     1902.0             251680.0  4380.26
# 7                 17098130     1871.5             136348.0  4475.01
# ...                    ...        ...                  ...      ...
# 1007              30330220     1305.2             395651.0  2713.83
# 1014              28200920     1331.2             357520.0  2732.22
# 1015              29549115     1356.2              21489.0  2731.20
# 1016              19740385     1355.3             251537.0  2698.63
# 1021              33648410     1319.0             349123.0  2681.66
#
# [566 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


#sns.pairplot(crypto)

#heatmap

fig, ax = plt.subplots(figsize=(10, 8))
# mask
mask = np.triu(np.ones_like(crypto, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = crypto.iloc[1:,:-1].copy()
# plot heatmap
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='Blues',
           vmin=-1, vmax=1, cbar_kws={"shrink": .8})
# yticks
plt.yticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dy/sbb0jsss1cnck9yj8m1qflxc0000gn/T/ipykernel_32674/84584070.py in <module>
#      10 fig, ax = plt.subplots(figsize=(10, 8))
#      11 # mask
# ---> 12 mask = np.triu(np.ones_like(crypto[:,1:], dtype=np.bool))
#      13 # adjust mask and df
#      14 mask = mask[1:, :-1]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(1, None, None))' is an invalid key
